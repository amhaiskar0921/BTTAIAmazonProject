# %% [markdown]
# <a href="https://colab.research.google.com/github/amhaiskar0921/BTTAIAmazonProject/blob/main/FinalLogsiticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_merged = pd.read_csv('/content/drive/MyDrive/Amazon (LA) - Multi-Class Product Classification (Team A)/Datasets/balanced_preprocessed_merged_data.csv')
df_merged.head(20)
# Out:
#     product_id product_locale  \
# 0   B0743Z7W7L             us
# 1   B076SZ62X2             us
# 2   B07JYZ55DQ             es
# 3   B07YD9M3YW             es
# 4   B00H6Z4LI4             jp
# 5   B00I59FM9M             jp
# 6   B00BS2HQ42             us
# 7   B013RA3H7M             jp
# 8   4091065058             jp
# 9   B00BN9UOP8             us
# 10  B07QM85F29             us
# 11  0781799155             us
# 12  B078YD277Z             us
# 13  B07KW2QZMJ             us
# 14  B073TRNRKV             us
# 15  B06XSZPFH6             es
# 16  B00NEAH3TE             us
# 17  0736431055             us
# 18  B074FFKWLM             us
# 19  B00L0UEEPG             jp
#
#                                         product_title  \
# 0   megaman retro arcad 8 bite decal mega man stic...
# 1   hikig car headrest mount holder kid kindl fire...
# 2   lijumn performance etiqueta engomado fibra car...
# 3   jztrading alfombrar titular baño tira resisten...
# 4           kindle paperwhite 専用 小型 usb 充電 器 505 0003
# 5   下村 企 販 バター ナイフ 2 本 組 日本 製 ステンレス マーガリン ジャム 2697...
# 6                       rug 10055 gun stock accessori
# 7         suzuki スズキ ミニ ハーモニカ minore 5 穴 10 音 mhk 5 r
# 8   ファイアー エムブレム 覚醒 ワンダー ライフ スペシャル nintendo 3 ds 任天...
# 9   char broil big easi 22 piec turkey fryer acces...
# 10  hybsk clear oil chang servic remind sticker 2 ...
# 11                    essenti clinic anatomi 4th edit
# 12  twin peak low carb keto friendli protein puff ...
# 13  aproca hard storag travel case bestek univers ...
# 14  juxzh soft front dog har best reflect pull har...
# 15  homcom soporte estante ajustable barra levanta...
# 16  quiksilv men time long sleev surf tee rashguar...
# 17                                   shape color coun
# 18  allinonepart lead back bumper light rear light...
# 19                                    消せ ない 罪 karaoke
#
#                                   product_description  \
# 0   mega man retro 8 bite decal easi appli vehicl ...
# 1   hikig car headrest mount holder kid kindl fire...
# 2                                                 NaN
# 3   color neromateriale osito gomadimensión prodot...
# 4                                                 NaN
# 5                                                 NaN
# 6   rug gear 10055 screw mount gun rack black stee...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  twin peak ingredi believ push health peak prot...
# 13  aproca hard storag travel case bag bestek univ...
# 14  dog har stylish safe durabl juxzh truelov dog ...
# 15  soporte pesa homcom suficientemente estable se...
# 16                                                NaN
# 17                                                NaN
# 18  add safeti significantli increas visibl honda ...
# 19                                                NaN
#
#                       product_brand esci_label  \
# 0                  decalcomania llc          C
# 1                             hikig          C
# 2                            lijumn          C
# 3                         jztrading          C
# 4                     和 湘 堂 washodo          C
# 5                            下村 企 販          C
# 6                          rug gear          C
# 7                        スズキ suzuki          C
# 8                              小学 館          C
# 9                        char broil          C
# 10                            hybsk          C
# 11  brand lippincott william wilkin          C
# 12                twin peak ingredi          C
# 13                           aproca          C
# 14                            juxzh          C
# 15                           homcom          C
# 16                         quiksilv          C
# 17                        rh disney          C
# 18                     allinonepart          C
# 19                              NaN          C
#
#                               query  bert_input
# 0         bass action figur megaman         NaN
# 1                        tablet car         NaN
# 2              bmw x3 pegatín llave         NaN
# 3                   alfombra cocina         NaN
# 4           whitepaper kindle 広告 なし         NaN
# 5                       バター 風 マーガリン         NaN
# 6                    gun rack truck         NaN
# 7                       ハーモニカ ペンダント         NaN
# 8                    ファイアー エムブレム 覚醒         NaN
# 9                         air fryer         NaN
# 10                  oil chang equip         NaN
# 11  moor essenti clinic anatomi 6th         NaN
# 12                       quest chip         NaN
# 13                    210 110 adapt         NaN
# 14                      juliu k9 xl         NaN
# 15               sentadilla soporte         NaN
# 16              men long swim trunk         NaN
# 17                          car toy         NaN
# 18             headlight honda jazz         NaN
# 19                          消せ ない 罪         NaN

# %%
df_merged.drop(columns=["bert_input", "product_id"], inplace=True)
df_merged.head()
# Out:
#   product_locale                                      product_title  \
# 0             us  megaman retro arcad 8 bite decal mega man stic...
# 1             us  hikig car headrest mount holder kid kindl fire...
# 2             es  lijumn performance etiqueta engomado fibra car...
# 3             es  jztrading alfombrar titular baño tira resisten...
# 4             jp          kindle paperwhite 専用 小型 usb 充電 器 505 0003
#
#                                  product_description     product_brand  \
# 0  mega man retro 8 bite decal easi appli vehicl ...  decalcomania llc
# 1  hikig car headrest mount holder kid kindl fire...             hikig
# 2                                                NaN            lijumn
# 3  color neromateriale osito gomadimensión prodot...         jztrading
# 4                                                NaN     和 湘 堂 washodo
#
#   esci_label                      query
# 0          C  bass action figur megaman
# 1          C                 tablet car
# 2          C       bmw x3 pegatín llave
# 3          C            alfombra cocina
# 4          C    whitepaper kindle 広告 なし

# %%
df_merged.fillna("", inplace=True)
df_merged.head()
# Out:
#   product_locale                                      product_title  \
# 0             us  megaman retro arcad 8 bite decal mega man stic...
# 1             us  hikig car headrest mount holder kid kindl fire...
# 2             es  lijumn performance etiqueta engomado fibra car...
# 3             es  jztrading alfombrar titular baño tira resisten...
# 4             jp          kindle paperwhite 専用 小型 usb 充電 器 505 0003
#
#                                  product_description     product_brand  \
# 0  mega man retro 8 bite decal easi appli vehicl ...  decalcomania llc
# 1  hikig car headrest mount holder kid kindl fire...             hikig
# 2                                                               lijumn
# 3  color neromateriale osito gomadimensión prodot...         jztrading
# 4                                                        和 湘 堂 washodo
#
#   esci_label                      query
# 0          C  bass action figur megaman
# 1          C                 tablet car
# 2          C       bmw x3 pegatín llave
# 3          C            alfombra cocina
# 4          C    whitepaper kindle 広告 なし

# %% [markdown]
# ##Preparing data for logistic regression

# %% [markdown]
# ### Step 1: Combine Text Columns

# %%
# Create a new column for BERT input
df_merged['lr_input'] = ""

# Apply functions based on the language specified in the product_locale column
for index, row in df_merged.iterrows():
    locale = row['product_locale']
    query_text = row['query']
    title_text = row['product_title']
    description_text = row['product_description']
    brand_text = row['product_brand']


    lr_input = f'{query_text} {title_text} {description_text} {brand_text}'
    df_merged.at[index, 'lr_input'] = lr_input

# %%
df_merged.head()
# Out:
#   product_locale                                      product_title  \
# 0             us  megaman retro arcad 8 bite decal mega man stic...
# 1             us  hikig car headrest mount holder kid kindl fire...
# 2             es  lijumn performance etiqueta engomado fibra car...
# 3             es  jztrading alfombrar titular baño tira resisten...
# 4             jp          kindle paperwhite 専用 小型 usb 充電 器 505 0003
#
#                                  product_description     product_brand  \
# 0  mega man retro 8 bite decal easi appli vehicl ...  decalcomania llc
# 1  hikig car headrest mount holder kid kindl fire...             hikig
# 2                                                               lijumn
# 3  color neromateriale osito gomadimensión prodot...         jztrading
# 4                                                        和 湘 堂 washodo
#
#   esci_label                      query  \
# 0          C  bass action figur megaman
# 1          C                 tablet car
# 2          C       bmw x3 pegatín llave
# 3          C            alfombra cocina
# 4          C    whitepaper kindle 広告 なし
#
#                                             lr_input
# 0  bass action figur megaman megaman retro arcad ...
# 1  tablet car hikig car headrest mount holder kid...
# 2  bmw x3 pegatín llave lijumn performance etique...
# 3  alfombra cocina jztrading alfombrar titular ba...
# 4  whitepaper kindle 広告 なし kindle paperwhite 専用 小...

# %% [markdown]
# ### Step 2: Tokenization with Count Vectors

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer()
X_count = count_vectorizer.fit_transform(df_merged['lr_input'])

# %% [markdown]
# ####Scaling X-count because we were getting convergence errors with the logistic regression model

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler(with_mean=False)
X_count_scaled = scaler.fit_transform(X_count)

# %% [markdown]
# ### Step 3: Tokenization with TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
X_tfidf = tfidf_vectorizer.fit_transform(df_merged['lr_input'])

# %%
label_map = {"E": 0, "S": 1, "C": 2, "I": 3}

# Assuming df_merged is your DataFrame containing the "esci_label" column
df_merged["esci_label"] = df_merged["esci_label"].map(label_map)

# %%
df_merged.head()
# Out:
#   product_locale                                      product_title  \
# 0             us  megaman retro arcad 8 bite decal mega man stic...
# 1             us  hikig car headrest mount holder kid kindl fire...
# 2             es  lijumn performance etiqueta engomado fibra car...
# 3             es  jztrading alfombrar titular baño tira resisten...
# 4             jp          kindle paperwhite 専用 小型 usb 充電 器 505 0003
#
#                                  product_description     product_brand  \
# 0  mega man retro 8 bite decal easi appli vehicl ...  decalcomania llc
# 1  hikig car headrest mount holder kid kindl fire...             hikig
# 2                                                               lijumn
# 3  color neromateriale osito gomadimensión prodot...         jztrading
# 4                                                        和 湘 堂 washodo
#
#    esci_label                      query  \
# 0           2  bass action figur megaman
# 1           2                 tablet car
# 2           2       bmw x3 pegatín llave
# 3           2            alfombra cocina
# 4           2    whitepaper kindle 広告 なし
#
#                                             lr_input
# 0  bass action figur megaman megaman retro arcad ...
# 1  tablet car hikig car headrest mount holder kid...
# 2  bmw x3 pegatín llave lijumn performance etique...
# 3  alfombra cocina jztrading alfombrar titular ba...
# 4  whitepaper kindle 広告 なし kindle paperwhite 専用 小...

# %%
y = df_merged['esci_label']

# %% [markdown]
# ### Step 4: Train Logistic Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_count_train, X_count_test, y_train, y_test = train_test_split(X_count_scaled, y, test_size=0.2, random_state=42)
X_tfidf_train, X_tfidf_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %% [markdown]
# ###Training + getting overall f1-score

# %%
from sklearn.metrics import f1_score, classification_report

# %%
# Initialize and train the logistic regression model on count vectors
logreg_count_model = LogisticRegression()
logreg_count_model.fit(X_count_train, y_train)
y_count_pred = logreg_count_model.predict(X_count_test)
f1_score_total = f1_score(y_test, y_count_pred, average='micro')
print(f'Count Vectors micro-avg F1-score: {f1_score_total}')
# Out:
# Count Vectors micro-avg F1-score: 0.3891147020918014
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Initialize and train the logistic regression model on TF-IDF vectors
logreg_tfidf_model = LogisticRegression()
logreg_tfidf_model.fit(X_tfidf_train, y_train)
y_tfidf_pred = logreg_tfidf_model.predict(X_tfidf_test)
f1_score_total = f1_score(y_test, y_tfidf_pred, average='micro')
print(f'TF-IDF micro-avg F1-score: {f1_score_total}')
# Out:
# TF-IDF micro-avg F1-score: 0.42297015961138096
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(y_tfidf_pred)
# Out:
# [0 0 2 ... 3 1 2]

# %%
report = classification_report(y_test, y_tfidf_pred, target_names=['E', 'S', 'C', 'I'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            E       0.37      0.35      0.36      5188
#            S       0.37      0.34      0.35      5000
#            C       0.53      0.60      0.56      5057
#            I       0.41      0.41      0.41      4929
#
#     accuracy                           0.42     20174
#    macro avg       0.42      0.42      0.42     20174
# weighted avg       0.42      0.42      0.42     20174

# %% [markdown]
# ###f1-score: English

# %%
english_data = df_merged[df_merged['product_locale'] == 'us']
english_data.head()
# Out:
#    product_locale                                      product_title  \
# 0              us  megaman retro arcad 8 bite decal mega man stic...
# 1              us  hikig car headrest mount holder kid kindl fire...
# 6              us                      rug 10055 gun stock accessori
# 9              us  char broil big easi 22 piec turkey fryer acces...
# 10             us  hybsk clear oil chang servic remind sticker 2 ...
#
#                                   product_description     product_brand  \
# 0   mega man retro 8 bite decal easi appli vehicl ...  decalcomania llc
# 1   hikig car headrest mount holder kid kindl fire...             hikig
# 6   rug gear 10055 screw mount gun rack black stee...          rug gear
# 9                                                            char broil
# 10                                                                hybsk
#
#     esci_label                      query  \
# 0            2  bass action figur megaman
# 1            2                 tablet car
# 6            2             gun rack truck
# 9            2                  air fryer
# 10           2            oil chang equip
#
#                                              lr_input
# 0   bass action figur megaman megaman retro arcad ...
# 1   tablet car hikig car headrest mount holder kid...
# 6   gun rack truck rug 10055 gun stock accessori r...
# 9   air fryer char broil big easi 22 piec turkey f...
# 10  oil chang equip hybsk clear oil chang servic r...

# %%
from sklearn.metrics import classification_report

count_vectorizer_en = CountVectorizer()
tfidf_vectorizer_en = TfidfVectorizer()

# Assuming df_merged is your DataFrame with 'product_locale' column
# Replace 'esci_label' with your actual label column

# English Subset
english_data = df_merged[df_merged['product_locale'] == 'us']
X_count_en = count_vectorizer_en.fit_transform(english_data['lr_input'])
X_tfidf_en = tfidf_vectorizer_en.fit_transform(english_data['lr_input'])
y_en = english_data['esci_label']
X_train_count_en, X_test_count_en, y_train_en, y_test_en = train_test_split(X_count_en, y_en, test_size=0.2, random_state=42)
X_train_tfidf_en, X_test_tfidf_en, _, _ = train_test_split(X_tfidf_en, y_en, test_size=0.2, random_state=42)

# Train Logistic Regression Models
logreg_model_count_en = LogisticRegression()
logreg_model_count_en.fit(X_train_count_en, y_train_en)

logreg_model_tfidf_en = LogisticRegression()
logreg_model_tfidf_en.fit(X_train_tfidf_en, y_train_en)

# Evaluate Models
y_pred_count_en = logreg_model_count_en.predict(X_test_count_en)
f1_score_count_en = f1_score(y_test_en, y_pred_count_en, average='micro')
print(f'TF-IDF micro-avg F1-score (English), before tf-idf: {f1_score_count_en}')

y_pred_tfidf_en = logreg_model_tfidf_en.predict(X_test_tfidf_en)

f1_score_en = f1_score(y_test_en, y_pred_tfidf_en, average='micro')
print(f'TF-IDF micro-avg F1-score (English): {f1_score_en}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# TF-IDF micro-avg F1-score (English), before tf-idf: 0.37237308146399056
# TF-IDF micro-avg F1-score (English): 0.40070838252656427
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ###f1-score: Spanish

# %%
# Spanish Subset
spanish_data = df_merged[df_merged['product_locale'] == 'es']
X_count_es = count_vectorizer_en.transform(spanish_data['lr_input'])
X_tfidf_es = tfidf_vectorizer_en.transform(spanish_data['lr_input'])
y_es = spanish_data['esci_label']
X_train_count_es, X_test_count_es, y_train_es, y_test_es = train_test_split(X_count_es, y_es, test_size=0.2, random_state=42)
X_train_tfidf_es, X_test_tfidf_es, _, _ = train_test_split(X_tfidf_es, y_es, test_size=0.2, random_state=42)

# Train Logistic Regression Models
logreg_model_count_es = LogisticRegression()
logreg_model_count_es.fit(X_train_count_es, y_train_es)

logreg_model_tfidf_es = LogisticRegression()
logreg_model_tfidf_es.fit(X_train_tfidf_es, y_train_es)

# Evaluate Models
y_pred_count_es = logreg_model_count_es.predict(X_test_count_es)
f1_score_count_es = f1_score(y_test_es, y_pred_count_es, average='micro')
print(f'TF-IDF micro-avg F1-score (Spanish): {f1_score_count_es}')

y_pred_tfidf_es = logreg_model_tfidf_es.predict(X_test_tfidf_es)
f1_score_es = f1_score(y_test_es, y_pred_tfidf_es, average='micro')
print(f'TF-IDF micro-avg F1-score (Spanish): {f1_score_es}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# TF-IDF micro-avg F1-score (Spanish): 0.4078837014257758
# TF-IDF micro-avg F1-score (Spanish): 0.45149566675985464
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
spanish_data.head()
# Out:
#    product_locale                                      product_title  \
# 2              es  lijumn performance etiqueta engomado fibra car...
# 3              es  jztrading alfombrar titular baño tira resisten...
# 15             es  homcom soporte estante ajustable barra levanta...
# 22             es  ibàstir cajo disco duro 2 5 pulgada caja exter...
# 29             es            kärcher acolchado acolchado 2 885 018 0
#
#                                   product_description product_brand  \
# 2                                                            lijumn
# 3   color neromateriale osito gomadimensión prodot...     jztrading
# 15  soporte pesa homcom suficientemente estable se...        homcom
# 22  parámetro técnico utilizar chip controlador jm...        ibàste
# 29  boquilla lavado conducción manual pulverizació...       kärcher
#
#     esci_label                 query  \
# 2            2  bmw x3 pegatín llave
# 3            2       alfombra cocina
# 15           2    sentadilla soporte
# 22           2      ssd 1 tb interno
# 29           2        lavaaspiradora
#
#                                              lr_input
# 2   bmw x3 pegatín llave lijumn performance etique...
# 3   alfombra cocina jztrading alfombrar titular ba...
# 15  sentadilla soporte homcom soporte estante ajus...
# 22  ssd 1 tb interno ibàstir cajo disco duro 2 5 p...
# 29  lavaaspiradora kärcher acolchado acolchado 2 8...

# %% [markdown]
# ###f1-score: Japanese

# %%
# Japanese Subset
japanese_data = df_merged[df_merged['product_locale'] == 'jp']
X_count_jp = count_vectorizer_en.transform(japanese_data['lr_input'])
X_tfidf_jp = tfidf_vectorizer_en.transform(japanese_data['lr_input'])
y_jp = japanese_data['esci_label']
X_train_count_jp, X_test_count_jp, y_train_jp, y_test_jp = train_test_split(X_count_jp, y_jp, test_size=0.2, random_state=42)
X_train_tfidf_jp, X_test_tfidf_jp, _, _ = train_test_split(X_tfidf_jp, y_jp, test_size=0.2, random_state=42)

# Train Logistic Regression Models
logreg_model_count_jp = LogisticRegression()
logreg_model_count_jp.fit(X_train_count_jp, y_train_jp)

logreg_model_tfidf_jp = LogisticRegression()
logreg_model_tfidf_jp.fit(X_train_tfidf_jp, y_train_jp)

# Evaluate Models
y_pred_count_jp = logreg_model_count_jp.predict(X_test_count_jp)
f1_score_count_jp = f1_score(y_test_jp, y_pred_count_jp, average='micro')
print(f'TF-IDF micro-avg F1-score (Japanese): {f1_score_count_jp}')

y_pred_tfidf_jp = logreg_model_tfidf_jp.predict(X_test_tfidf_jp)
f1_score_jp = f1_score(y_test_jp, y_pred_tfidf_jp, average='micro')
print(f'TF-IDF micro-avg F1-score (Japanese): {f1_score_jp}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# TF-IDF micro-avg F1-score (Japanese): 0.3650141279219111
# TF-IDF micro-avg F1-score (Japanese): 0.3747752376059595
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# iterations = [i for i in range(len(f1_score_jp))]
# f1_score_jp = f1_score(y_test_jp, y_pred_tfidf_jp, average='micro')

# plt.plot(iterations, f1_score_jp, label='Japanese', marker='o')
# plt.plot(iterations, f1_score_en, label='English', marker='o')
# plt.plot(iterations, f1_score_es, label='Spanish', marker='o')
# plt.xlabel('Iterations')
# plt.ylabel('F1 Score')
# plt.title('F1 Score versus Iterations')
# plt.legend()
# plt.show()


from wordcloud import WordCloud

# Combining all text data into a single string
df = pd.read_csv('/content/drive/MyDrive/Amazon (LA) - Multi-Class Product Classification (Team A)/Datasets/preprocessed_merged_data.csv')

text_data = ' '.join(df['product_description'].astype(str))

wordcloud = WordCloud(width=800, height=800, background_color='white',
                      min_font_size=10).generate(text_data)

plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.title('Word Cloud for Text Data')
plt.show()
